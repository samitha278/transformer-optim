# %% [markdown]
# <a href="https://colab.research.google.com/github/samitha278/transformer-optim/blob/main/finetune.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## LLama 3.2 vision model

# %%
# vision encoder

    # encoder layes -> local
        # rmsnorm
        # attention - gqa
        # rmsnorm
        # glu
        # output each layer

    # encoder layers global
        # rmsnorm
        # attention
        # rmsnorm
        # glu
        # pass to next layer

    # concatenate outputs
    # linear projector

# llm

    # decoder layers
    # cross attention layers
    # rmsnorm
    # linear proj

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
